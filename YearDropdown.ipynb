# %%
import pandas as pd
import datetime as dt

# %%
# Pull in fireball csv data
fireball_years = pd.read_csv("Resources/Fireball_Data_Years.csv")
fireball_years
# Out:
#      Unnamed: 0  Peak Brightness Date/Time (UT) Latitude (deg.)  \
# 0             0                            2021           5.15N
# 1             1                            2021           13.8N
# 2             2                            2021           59.0N
# 3             3                            2021           53.9N
# 4             4                            2021            2.1S
# ..          ...                             ...             ...
# 684         684                            1994            2.7N
# 685         685                            1993           26.5N
# 686         686                            1993           51.3N
# 687         687                            1991           78.7N
# 688         688                            1990            7.5N
#
#     Longitude (deg.)  Altitude (km)  Velocity (km/s)    vx   vy    vz  \
# 0              51.4E           29.0             15.3 -13.6 -6.8  -1.7
# ...

# %%
#pull in meterorite data
fireball_years = fireball_years.rename(columns ={'Peak Brightness Date/Time (UT)':'year'})
fireball_years
# Out:
#      Unnamed: 0  year Latitude (deg.) Longitude (deg.)  Altitude (km)  \
# 0             0  2021           5.15N            51.4E           29.0
# 1             1  2021           13.8N           140.4W           28.0
# 2             2  2021           59.0N           154.3E           31.4
# 3             3  2021           53.9N           148.0W           28.0
# 4             4  2021            2.1S           111.8W           26.0
# ..          ...   ...             ...              ...            ...
# 684         684  1994            2.7N           164.1E            NaN
# 685         685  1993           26.5N            78.3E            NaN
# 686         686  1993           51.3N           100.9W            NaN
# 687         687  1991           78.7N             6.3E            NaN
# 688         688  1990            7.5N           142.8E            NaN
#
#      Velocity (km/s)    vx   vy    vz  Total Radiated Energy (J)  \
# ...

# %%
#drop columns to year, for bullet altitude graph to graph mean, max, min for each year
fireball_years=fireball_years.drop(columns=['Unnamed: 0','Latitude (deg.)','Longitude (deg.)','Velocity (km/s)','vx','vy','vz','Total Radiated Energy (J)','Calculated Total Impact Energy (kt)'])

# %%
fireball_years
# Out:
#      year  Altitude (km)
# 0    2021           29.0
# 1    2021           28.0
# 2    2021           31.4
# 3    2021           28.0
# 4    2021           26.0
# ..    ...            ...
# 684  1994            NaN
# 685  1993            NaN
# 686  1993            NaN
# 687  1991            NaN
# 688  1990            NaN
#
# [689 rows x 2 columns]

# %%
#pull out year and altitude
fireball_years=fireball_years.dropna()
fireball_years
# Out:
#      year  Altitude (km)
# 0    2021           29.0
# 1    2021           28.0
# 2    2021           31.4
# 3    2021           28.0
# 4    2021           26.0
# ..    ...            ...
# 627  1999           69.0
# 637  1999           32.0
# 638  1999           65.0
# 643  1998           30.0
# 647  1997           37.0
#
# [433 rows x 2 columns]

# %%
#group by year
altitude_mean = fireball_years.groupby(['year',], as_index=False)['Altitude (km)'].mean()
altitude_mean = altitude_mean.rename(columns ={'Altitude (km)':'Alt_mean (km)'})
altitude_mean.head(5)
# Out:
#    year  Alt_mean (km)
# 0  1997           37.0
# 1  1998           30.0
# 2  1999           50.0
# 3  2000           48.0
# 4  2001           29.0

# %%
altitude_min = fireball_years.groupby(['year',], as_index=False)['Altitude (km)'].min()
altitude_min = altitude_min.rename(columns ={'Altitude (km)':'Alt_min (km)'})
altitude_min.head(5)
# Out:
#    year  Alt_min (km)
# 0  1997          37.0
# 1  1998          30.0
# 2  1999          32.0
# 3  2000          48.0
# 4  2001          29.0

# %%
altitude_max = fireball_years.groupby(['year',], as_index=False)['Altitude (km)'].max()
altitude_max = altitude_max.rename(columns ={'Altitude (km)':'Alt_max (km)'})
altitude_max.head(5)
# Out:
#    year  Alt_max (km)
# 0  1997          37.0
# 1  1998          30.0
# 2  1999          69.0
# 3  2000          48.0
# 4  2001          29.0

# %%
#merge min and max
min_mean=altitude_min.merge(altitude_mean, how='outer').round(1)
min_mean.head(5)
# Out:
#    year  Alt_min (km)  Alt_mean (km)
# 0  1997          37.0           37.0
# 1  1998          30.0           30.0
# 2  1999          32.0           50.0
# 3  2000          48.0           48.0
# 4  2001          29.0           29.0

# %%
#merge in mean
fb_altitude=min_mean.merge(altitude_max, how='outer').round(1)
fb_altitude.head(5)
# Out:
#    year  Alt_min (km)  Alt_mean (km)  Alt_max (km)
# 0  1997          37.0           37.0          37.0
# 1  1998          30.0           30.0          30.0
# 2  1999          32.0           50.0          69.0
# 3  2000          48.0           48.0          48.0
# 4  2001          29.0           29.0          29.0

# %%
fb_altitude =fb_altitude.sort_values(['year'], ascending=False)
fb_altitude.head(5)
# Out:
#     year  Alt_min (km)  Alt_mean (km)  Alt_max (km)
# 23  2021          19.1           33.4          63.0
# 22  2020          14.5           33.1          52.5
# 21  2019          19.5           34.9          61.5
# 20  2018          26.0           34.8          63.0
# 19  2017          20.0           35.0          64.5

# %%
fb_altitude.to_csv('Resources/fb_altitude.csv')

# %%
#meterorite for year db only
m = pd.read_csv("Resources/Meteorite_Landings_Years.csv")
m
# Out:
#        Unnamed: 0        name     id nametype              recclass  mass (g)  \
# 0               0      Aarhus      2    Valid                    H6     720.0
# 1               1        Abee      6    Valid                   EH4  107000.0
# 2               2    Acapulco     10    Valid           Acapulcoite    1914.0
# 3               3     Achiras    370    Valid                    L6     780.0
# 4               4    Adhi Kot    379    Valid                   EH4    4239.0
# ...           ...         ...    ...      ...                   ...       ...
# 44638       44638  Zillah 002  31356    Valid               Eucrite     172.0
# 44639       44639      Zinder  30409    Valid  Pallasite, ungrouped      46.0
# 44640       44640        Zlin  30410    Valid                    H4       3.3
# 44641       44641   Zubkovsky  31357    Valid                    L6    2167.0
# 44642       44642  Zulu Queen  30414    Valid                  L3.7     200.0
#
# ...

# %%
#fireball for year db only
fb = pd.read_csv("Resources/Fireball_Data_Years.csv")
fb = fb.rename(columns ={'Peak Brightness Date/Time (UT)':'year'})
fb
# Out:
#      Unnamed: 0  year Latitude (deg.) Longitude (deg.)  Altitude (km)  \
# 0             0  2021           5.15N            51.4E           29.0
# 1             1  2021           13.8N           140.4W           28.0
# 2             2  2021           59.0N           154.3E           31.4
# 3             3  2021           53.9N           148.0W           28.0
# 4             4  2021            2.1S           111.8W           26.0
# ..          ...   ...             ...              ...            ...
# 684         684  1994            2.7N           164.1E            NaN
# 685         685  1993           26.5N            78.3E            NaN
# 686         686  1993           51.3N           100.9W            NaN
# 687         687  1991           78.7N             6.3E            NaN
# 688         688  1990            7.5N           142.8E            NaN
#
#      Velocity (km/s)    vx   vy    vz  Total Radiated Energy (J)  \
# ...

# %%
#merge fireballs and meteorite for year df
merge=fb.merge(m, how='outer')
merge
# Out:
#        Unnamed: 0  year Latitude (deg.) Longitude (deg.)  Altitude (km)  \
# 0               0  2021           5.15N            51.4E           29.0
# 1               1  2021           13.8N           140.4W           28.0
# 2               2  2021           59.0N           154.3E           31.4
# 3               3  2021           53.9N           148.0W           28.0
# 4               4  2021            2.1S           111.8W           26.0
# ...           ...   ...             ...              ...            ...
# 45325       44638  1990             NaN              NaN            NaN
# 45326       44639  1999             NaN              NaN            NaN
# 45327       44640  1939             NaN              NaN            NaN
# 45328       44641  2003             NaN              NaN            NaN
# 45329       44642  1976             NaN              NaN            NaN
#
#        Velocity (km/s)    vx   vy    vz  Total Radiated Energy (J)  \
# ...

# %%
#drop extra columns
merge = merge.drop(columns={'Unnamed: 0','Latitude (deg.)','Longitude (deg.)','Altitude (km)','Velocity (km/s)','vx','vy','vz','Total Radiated Energy (J)','Calculated Total Impact Energy (kt)','name','id','nametype','recclass','mass (g)','fall','reclat','reclong','GeoLocation'})
merge
# Out:
#        year
# 0      2021
# 1      2021
# 2      2021
# 3      2021
# 4      2021
# ...     ...
# 45325  1990
# 45326  1999
# 45327  1939
# 45328  2003
# 45329  1976
#
# [45330 rows x 1 columns]

# %%
#place in descending order
year =merge.sort_values(['year'], ascending=False)
year
# Out:
#        year
# 30454  2101
# 0      2021
# 13     2021
# 1      2021
# 22     2021
# ...     ...
# 5407   1900
# 1027   1900
# 26301  1900
# 5645   1900
# 1151   1900
#
# [45330 rows x 1 columns]

# %%
#drop duplicates
year=year.drop_duplicates()
year
# Out:
#        year
# 30454  2101
# 0      2021
# 45     2020
# 89     2019
# 132    2018
# ...     ...
# 1140   1904
# 1220   1903
# 30690  1902
# 926    1901
# 868    1900
#
# [122 rows x 1 columns]

# %%
#drop year 2101 or index place [0]
year=year.drop(year.index[0])
year
# Out:
#        year
# 0      2021
# 45     2020
# 89     2019
# 132    2018
# 163    2017
# ...     ...
# 1140   1904
# 1220   1903
# 30690  1902
# 926    1901
# 868    1900
#
# [121 rows x 1 columns]

# %%
#save to csv
year.to_csv('Resources/year.csv')

# %%
#just in case
meteorite_years = pd.read_csv("Resources/Meteorite_Landings_Years.csv")
meteorite_years
# Out:
#        Unnamed: 0        name     id nametype              recclass  mass (g)  \
# 0               0      Aarhus      2    Valid                    H6     720.0
# 1               1        Abee      6    Valid                   EH4  107000.0
# 2               2    Acapulco     10    Valid           Acapulcoite    1914.0
# 3               3     Achiras    370    Valid                    L6     780.0
# 4               4    Adhi Kot    379    Valid                   EH4    4239.0
# ...           ...         ...    ...      ...                   ...       ...
# 44638       44638  Zillah 002  31356    Valid               Eucrite     172.0
# 44639       44639      Zinder  30409    Valid  Pallasite, ungrouped      46.0
# 44640       44640        Zlin  30410    Valid                    H4       3.3
# 44641       44641   Zubkovsky  31357    Valid                    L6    2167.0
# 44642       44642  Zulu Queen  30414    Valid                  L3.7     200.0
#
# ...

# %%
#meteorite only years if needed
meteorite_years = meteorite_years.drop(columns={'Unnamed: 0','name','id','nametype','recclass','mass (g)','fall','reclat','reclong','GeoLocation'})
meteorite_years=meteorite_years.drop_duplicates()
meteorite_years
# Out:
#        year
# 0      1951
# 1      1952
# 2      1976
# 3      1902
# 4      1919
# ...     ...
# 379    1953
# 380    1915
# 451    1958
# 1113   2005
# 29767  2101
#
# [114 rows x 1 columns]
